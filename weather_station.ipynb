# %%
import pandas as pd

df = pd.read_csv('Anjas.csv')

# %%
display(df.head(20), df.tail(10))
# Out:
#        tanggal  arah_angin  hujan  kelembaban  tekanan_udara  temperature  \
# 0   2023-10-15  barat           0         255       93905.15          255
# 1   2023-10-15  barat           0         255       93906.84          255
# 2   2023-10-15  barat           0         255       93907.17          255
# 3   2023-10-15  barat           0         255       93907.14          255
# 4   2023-10-15  barat           0         255       93906.92          255
# 5   2023-10-15  barat           0         255       93907.34          255
# 6   2023-10-15  barat           0         255       93906.88          255
# 7   2023-10-15  barat           0         255       93906.38          255
# 8   2023-10-15  barat           0         255       93905.70          255
# 9   2023-10-15  barat           0         255       93907.52          255
# 10  2023-10-15  barat           0         255       93908.13          255
# 11  2023-10-15  barat           0         255       93908.95          255
# ...
